# %%
# declare a list tasks whose products you want to use as inputs
upstream = None

# %%
# Parameters
some_param = "c"
product = "C:\\Users\\User\\Documents\\ploomber\\environmnets\\yafim-git-forked\\ploomber\\tests\\assets\\report-c.ipynb"

# %%
some_param = 'a'
product = None

# %%
print(f'hello {some_param}')
