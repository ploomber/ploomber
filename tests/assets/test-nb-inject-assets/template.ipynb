# %%
# declare a list tasks whose products you want to use as inputs
upstream = None

# %%
# Parameters
some_param = "a"
product = "C:\\Users\\User\\Documents\\ploomber\\environmnets\\yafim-git-forked\\ploomber\\tests\\assets\\test-nb-inject-assets\\report-a.ipynb"

# %%
some_param = 'a'
product = None

# %%
print(f'hello {some_param}')
